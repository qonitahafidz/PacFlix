# %%
#data preparation
import pandas as pd

df = pd.read_csv('insurance.csv')

df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#mengetahui informasi dari data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# metode untuk mengetahui deskriptif statistik data
import numpy as np
df1 = df.describe()
df1
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#sorting 
df2 = df.drop(['age', 'sex','bmi','children','region'],axis=1)
df2
# Out:
#      smoker      charges
# 0       yes  16884.92400
# 1        no   1725.55230
# 2        no   4449.46200
# 3        no  21984.47061
# 4        no   3866.85520
# ...     ...          ...
# 1333     no  10600.54830
# 1334     no   2205.98080
# 1335     no   1629.83350
# 1336     no   2007.94500
# 1337    yes  29141.36030
#
# [1338 rows x 2 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
from scipy.stats import norm
from scipy.stats import expon

# %%
data_array=np.array (df)
data_array
# Out:
# array([[19, 'female', 27.9, ..., 'yes', 'southwest', 16884.924],
#        [18, 'male', 33.77, ..., 'no', 'southeast', 1725.5523],
#        [28, 'male', 33.0, ..., 'no', 'southeast', 4449.462],
#        ...,
#        [18, 'female', 36.85, ..., 'no', 'southeast', 1629.8335],
#        [21, 'female', 25.8, ..., 'no', 'southwest', 2007.945],
#        [61, 'female', 29.07, ..., 'yes', 'northwest', 29141.3603]],
#       dtype=object)

# %%
#filter data tagihan kesehatan berdasarkan bmi
df3 = df.drop(['age', 'sex','smoker','children','region'],axis=1)
df3
# Out:
#          bmi      charges
# 0     27.900  16884.92400
# 1     33.770   1725.55230
# 2     33.000   4449.46200
# 3     22.705  21984.47061
# 4     28.880   3866.85520
# ...      ...          ...
# 1333  30.970  10600.54830
# 1334  31.920   2205.98080
# 1335  36.850   1629.83350
# 1336  25.800   2007.94500
# 1337  29.070  29141.36030
#
# [1338 rows x 2 columns]

# %%
#tagihan berdasarkan bmi
sns.relplot(data=df3,x="bmi",y='charges',hue="charges")
plt.show()

# %%
#menghitung varians
var_=np.var(df3)
print(var_)
# Out:
# bmi        3.716009e+01
# charges    1.465428e+08
# dtype: float64

# %% [markdown]
# #menghitung skewness (tagihan berdasarkan bmi)

# %%
print(scipy.stats.skew(df3, bias=False))
# Out:
# [0.28404711 1.51587966]

# %% [markdown]
# visualisasi data all variabels:

# %%
#visualisasi data
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
sns.pairplot(df[['age','bmi','children','smoker','region','charges']])
plt.show()

# %%
#tagihan berdasarkan usia
sns.relplot(data=df,x="age",y="charges",hue="charges")
plt.show()

# %%
#tagihan berdasarkan gender
sns.relplot(data=df,x="sex",y="charges",hue="charges",style="sex")
plt.show()

# %%
#tagihan berdasarkan kebiasaan merokok
sns.relplot(data=df,x="smoker",y="charges",hue="charges")
plt.show()

# %%
#region
df.region.value_counts().plot(kind='bar',color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#sortir charges saja
df4 = df.drop(['age', 'bmi', 'sex','smoker','children','region'],axis=1)
df4
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
data_array2=np.array (df4)
data_array2
# Out:
# array([[16884.924 ],
#        [ 1725.5523],
#        [ 4449.462 ],
#        ...,
#        [ 1629.8335],
#        [ 2007.945 ],
#        [29141.3603]])

# %%
plt.hist(data_array2, bins=30)
plt.xlabel("charges")
plt.show()

# %%
df[['charges', 'bmi']].corr()
# Out:
#           charges       bmi
# charges  1.000000  0.198341
# bmi      0.198341  1.000000

# %%
df[['charges', 'age']].corr()
# Out:
#           charges       age
# charges  1.000000  0.299008
# age      0.299008  1.000000

# %%
# load data
import pandas as pd
import numpy as np
import itertools
import random
from collections import Counter

# load distribution
from scipy.stats import binom

# visualization
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
import scipy.stats as stats
import math

# Menentukan jumlah kejadian ukuran sampel (n), proporsi pada null hypothesis, dan proporsi sample
n = 274
p = 0.5
p_hat = 0.580

# %%
# Hitung uji statistik
test_stat=(p_hat-p)/(math.sqrt((p*(1-p))/(n)))
print(test_stat)
# Out:
# 2.648471257159495

# %%
# Nilai Critical Value berdasarkan critical Z-value dari Z-table dengan nilai alpha 0.05
#Import package
import scipy.stats as stats
z_crit=stats.norm.ppf(1-0.05)  # right-tailed test
print(z_crit)
# Out:
# 1.6448536269514722

# %%
# Menentukan aturan keputusan
if test_stat>z_crit:
    print("Tolak null hypothesis")
else:
    print("Gagal tolak null hypothesis")
# Out:
# Tolak null hypothesis
